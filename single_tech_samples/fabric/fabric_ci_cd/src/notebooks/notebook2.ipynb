# %%
mssparkutils.fs.ls("Files/")

# %% [markdown]
# this is a [link](../../docs/setup_opentelemetry.md)

# %%
print(mssparkutils.runtime.context)

# %%
print(mssparkutils.env.getClusterId())
# Out:
# StatementMeta(, 7c90d845-5f63-471b-83d0-519099d8d961, 21, Finished, Available, Finished)
# 0cdd1ebd-f893-499e-8721-4e7ba4b88b94

# %%
print(mssparkutils.env.getPoolName())
# Out:
# StatementMeta(, , , Waiting, , Waiting)
# new-one

# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
import hackutils
dir(hackutils)
